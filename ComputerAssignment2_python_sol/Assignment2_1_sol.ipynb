# %%
## Assignment 2.1

# %%
# Python version: 3.11.4

# create a virtual environment
# vscode: Search bar -> Python: Select Interpreter -> .venv
# terminal: python -m venv /path/to/new/virtual/environment

# activate virtual environment:
# source .venv/bin/activate

# install requirements.txt file in virtual environment:
# pip install -r requirements.txt

# check installed packages:
# pip freeze

# %% [markdown]
# Introduction to YALMIP
# In these exercises we learn how to formulate different classes of optimization problems such that they can be parsed by YALMIP. This live script makes reference to the Exercise 1 in the handout.
# Run the sections one by one by clicking into the respective code window and hitting "Run Section". Sentences highlighted in bold give instructions on how to complete the given code. Code lines like this need to be completed by you:

# %%
import cvxpy as cp
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['text.usetex'] = True
print("Installed solvers = ",cp.installed_solvers())
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Installed solvers =  ['CLARABEL', 'ECOS', 'ECOS_BB', 'MOSEK', 'OSQP', 'SCIPY', 'SCS']

# %%
# I. Linear Programming
# Clean up
plt.close('all')

# Problem 1
x1 = cp.Variable()
x2 = cp.Variable()

constraints = [
    2 * x1 + x2 >= 1,
    x1 + 3 * x2 >= 1,
    x1 >= 0,
    x2 >= 0]

objective = cp.Minimize(x1 + x2)

problem = cp.Problem(objective, constraints)
problem.solve(verbose=True)

print("\n x1 = ",x1.value,"x2 = ",x2.value)

# Plot
x1_values = np.linspace(0, 1, 100)
x2_values = np.linspace(0, 1, 100)
X1, X2 = np.meshgrid(x1_values, x2_values)
Z = X1 + X2

plt.figure()
fx=plt.contour(X1, X2, Z, levels=np.arange(0, 2.1, 0.1), linestyles='dashed', colors='grey')
plt.clabel(fx, inline=1, fontsize=10) #Places values of f at the lines
plt.plot(x1_values, 1 - 2 * x1_values, label='$g_1(x)$', color='green')
plt.plot(x1_values, (1 - x1_values) / 3, label='$g_2(x)$', color='blue')
plt.scatter(x1.value, x2.value, color='red', marker='*', s=200, label='$x^*$')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.legend()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Feb 17 02:28:12 PM: Your problem has 2 variables, 4 constraints, and 0 parameters.
# (CVXPY) Feb 17 02:28:12 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 17 02:28:12 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 17 02:28:12 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 17 02:28:12 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:12 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Feb 17 02:28:12 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Feb 17 02:28:12 PM: Applying reduction Dcp2Cone
# (CVXPY) Feb 17 02:28:12 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 17 02:28:12 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Feb 17 02:28:12 PM: Applying reduction MOSEK
# (CVXPY) Feb 17 02:28:12 PM: Finished problem compilation (took 8.094e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:12 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Feb 17 02:28:12 PM: Problem
# (CVXPY) Feb 17 02:28:12 PM:   Name                   :
# (CVXPY) Feb 17 02:28:12 PM:   Objective sense        : maximize
# (CVXPY) Feb 17 02:28:12 PM:   Type                   : LO (linear optimization problem)
# (CVXPY) Feb 17 02:28:12 PM:   Constraints            : 2
# (CVXPY) Feb 17 02:28:12 PM:   Affine conic cons.     : 0
# (CVXPY) Feb 17 02:28:12 PM:   Disjunctive cons.      : 0
# (CVXPY) Feb 17 02:28:12 PM:   Cones                  : 0
# (CVXPY) Feb 17 02:28:12 PM:   Scalar variables       : 4
# (CVXPY) Feb 17 02:28:12 PM:   Matrix variables       : 0
# (CVXPY) Feb 17 02:28:12 PM:   Integer variables      : 0
# (CVXPY) Feb 17 02:28:12 PM:
# (CVXPY) Feb 17 02:28:12 PM: Optimizer started.
# (CVXPY) Feb 17 02:28:12 PM: Folding started.
# (CVXPY) Feb 17 02:28:12 PM: Folding: not applied.
# (CVXPY) Feb 17 02:28:12 PM: Folding terminated. Time: 0.00.
# (CVXPY) Feb 17 02:28:12 PM: Presolve started.
# (CVXPY) Feb 17 02:28:12 PM: Linear dependency checker started.
# (CVXPY) Feb 17 02:28:12 PM: Linear dependency checker terminated.
# (CVXPY) Feb 17 02:28:12 PM: Eliminator started.
# (CVXPY) Feb 17 02:28:12 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 17 02:28:12 PM: Eliminator terminated.
# (CVXPY) Feb 17 02:28:12 PM: Eliminator started.
# (CVXPY) Feb 17 02:28:12 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 17 02:28:12 PM: Eliminator terminated.
# (CVXPY) Feb 17 02:28:12 PM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Feb 17 02:28:12 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Feb 17 02:28:12 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Feb 17 02:28:12 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Feb 17 02:28:12 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Feb 17 02:28:12 PM: Presolve terminated. Time: 0.00
# (CVXPY) Feb 17 02:28:12 PM: Optimizer  - threads                : 10
# (CVXPY) Feb 17 02:28:12 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Feb 17 02:28:12 PM: Optimizer  - Constraints            : 2
# (CVXPY) Feb 17 02:28:12 PM: Optimizer  - Cones                  : 0
# (CVXPY) Feb 17 02:28:12 PM: Optimizer  - Scalar variables       : 4                 conic                  : 0
# (CVXPY) Feb 17 02:28:12 PM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Feb 17 02:28:12 PM: Factor     - setup time             : 0.00
# (CVXPY) Feb 17 02:28:12 PM: Factor     - dense det. time        : 0.00              GP order time          : 0.00
# (CVXPY) Feb 17 02:28:12 PM: Factor     - nonzeros before factor : 3                 after factor           : 3
# (CVXPY) Feb 17 02:28:12 PM: Factor     - dense dim.             : 0                 flops                  : 2.10e+01
# (CVXPY) Feb 17 02:28:12 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Feb 17 02:28:12 PM: 0   4.6e-01  1.3e-01  2.9e-01  0.00e+00   1.079832691e+00   1.098388616e+00   2.7e-01  0.01
# (CVXPY) Feb 17 02:28:12 PM: 1   5.3e-02  1.6e-02  3.4e-02  1.90e+00   6.313140581e-01   6.259106323e-01   3.1e-02  0.01
# (CVXPY) Feb 17 02:28:12 PM: 2   6.7e-04  2.0e-04  4.2e-04  1.09e+00   6.001446334e-01   6.000757229e-01   3.9e-04  0.01
# (CVXPY) Feb 17 02:28:12 PM: 3   6.7e-08  2.0e-08  4.2e-08  1.00e+00   6.000000145e-01   6.000000077e-01   4.0e-08  0.01
# (CVXPY) Feb 17 02:28:12 PM: 4   6.7e-12  2.0e-12  4.2e-12  1.00e+00   6.000000000e-01   6.000000000e-01   4.0e-12  0.01
# (CVXPY) Feb 17 02:28:12 PM: Optimizer terminated. Time: 0.01
# (CVXPY) Feb 17 02:28:12 PM:
# (CVXPY) Feb 17 02:28:12 PM:
# (CVXPY) Feb 17 02:28:12 PM: Interior-point solution summary
# (CVXPY) Feb 17 02:28:12 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Feb 17 02:28:12 PM:   Solution status : OPTIMAL
# (CVXPY) Feb 17 02:28:12 PM:   Primal.  obj: 6.0000000000e-01    nrm: 1e+00    Viol.  con: 1e-11    var: 0e+00
# (CVXPY) Feb 17 02:28:12 PM:   Dual.    obj: 6.0000000000e-01    nrm: 4e-01    Viol.  con: 0e+00    var: 1e-12
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:12 PM: Problem status: optimal
# (CVXPY) Feb 17 02:28:12 PM: Optimal value: 6.000e-01
# (CVXPY) Feb 17 02:28:12 PM: Compilation took 8.094e-03 seconds
# (CVXPY) Feb 17 02:28:12 PM: Solver (including time spent in interface) took 5.808e-02 seconds
#
#  x1 =  0.4000000000005252 x2 =  0.20000000000024265
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18617: UserWarning: Argument sub in putvarboundlist: Incorrect array format causing data to be copied
#   warnings.warn("Argument sub in putvarboundlist: Incorrect array format causing data to be copied");
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18925: UserWarning: Argument subj in putclist: Incorrect array format causing data to be copied
#   warnings.warn("Argument subj in putclist: Incorrect array format causing data to be copied");
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18349: UserWarning: Argument sub in putconboundlist: Incorrect array format causing data to be copied
#   warnings.warn("Argument sub in putconboundlist: Incorrect array format causing data to be copied");

# %%
# II. Quadratic Programming

# Clean up
plt.close('all')

# Problem 2
x1 = cp.Variable()
x2 = cp.Variable()

constraints = [
    2 * x1 + x2 <= 10,
    x1 + x2 <= 8,
    x1 <= 4
]

objective = cp.Minimize((x1 - 5)**2 + (x2 - 5)**2)
problem = cp.Problem(objective, constraints)
problem.solve(verbose=True)

# Plot
x1_values = np.linspace(2, 5, 100)
x2_values = np.linspace(3, 6, 100)
X1, X2 = np.meshgrid(x1_values, x2_values)
Z = (X1 - 5)**2 + (X2 - 5)**2

plt.figure()
fx=plt.contour(X1, X2, Z, levels=np.arange(0, 30, 2), linestyles='dashed', colors='grey')
plt.clabel(fx, inline=1, fontsize=10) #Places values of f at the lines
plt.plot(x1_values, 10 - 2 * x1_values, color='green', label='$g_1(x)$')
plt.plot(x1_values, 8 - x1_values, color='blue', label='$g_2(x)$')
plt.plot(x1_values, 4 + 0 * x1_values, color='orange',label='$g_3(x)$')
plt.scatter(x1.value, x2.value, color='red', marker='*', s=200, label='$x^*$')
plt.grid(True)
plt.xlim([2, 5])
plt.ylim([3, 6])
plt.legend()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Feb 17 02:28:22 PM: Your problem has 2 variables, 3 constraints, and 0 parameters.
# (CVXPY) Feb 17 02:28:22 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 17 02:28:22 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 17 02:28:22 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 17 02:28:22 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:22 PM: Compiling problem (target solver=OSQP).
# (CVXPY) Feb 17 02:28:22 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Feb 17 02:28:22 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 17 02:28:22 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Feb 17 02:28:22 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Feb 17 02:28:22 PM: Applying reduction OSQP
# (CVXPY) Feb 17 02:28:22 PM: Finished problem compilation (took 5.510e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:22 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 4, constraints m = 5
#           nnz(P) + nnz(A) = 11
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   5.00e+00   9.99e+02   1.00e-01   5.90e-05s
#   75   5.0000e+00   4.31e-06   7.69e-08   1.00e-01   1.26e-04s
# plsh   5.0000e+00   6.28e-16   9.96e-16   --------   2.04e-04s
#
# status:               solved
# solution polish:      successful
# number of iterations: 75
# optimal objective:    5.0000
# run time:             2.04e-04s
# optimal rho estimate: 4.73e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:22 PM: Problem status: optimal
# (CVXPY) Feb 17 02:28:22 PM: Optimal value: 5.000e+00
# (CVXPY) Feb 17 02:28:22 PM: Compilation took 5.510e-03 seconds
# (CVXPY) Feb 17 02:28:22 PM: Solver (including time spent in interface) took 8.483e-04 seconds

# %%
# III. Semidefinite Programming

# Define constraints of the polytope in the form Ax + b <= 0
A = np.array([[-2, 1], [1, 4], [2, 2], [1, 0], [-2, 10]])
b = np.array([-2, -5, -4, -2, 8])

# Define variables
P = cp.Variable((2, 2), PSD=True)

# Define constraints
constraints = []
for i in range(A.shape[0]):
    constraints.append(cp.quad_form(A[i], P) - b[i]**2 <= 0)

# Define objective
objective = cp.Minimize(-cp.log_det(P))

# Solve SDP
prob = cp.Problem(objective, constraints)
prob.solve(solver=cp.MOSEK, verbose=True)

# Print solution
print("Optimal value (logdet(P)): ", prob.value)
P_sol = P.value;
print("Optimal solution (P): \n", P_sol)

## Plot the solution
plt.figure(figsize=(6, 6))
x_points = np.linspace(-3, 3, 100)
for i in range(A.shape[0]):
    if np.abs(A[i, 1]) > np.finfo(float).eps:
        plt.plot(x_points, -(A[i, 0] / A[i, 1]) * x_points - b[i] / A[i, 1], '-k', linewidth=2)
    else:
        plt.plot(-b[i] / A[i, 0] * np.array([1, 1]), np.array([-3, 3]), '-k', linewidth=2)

theta = np.linspace(0, 2 * np.pi, 1000)
y = np.vstack((np.cos(theta), np.sin(theta)))
eigenvalues, eigenvector = np.linalg.eig(np.linalg.inv(P_sol))
T = eigenvector @ np.linalg.inv(np.sqrt(np.diag(eigenvalues)))
x = T @ y

plt.plot(x[0], x[1], linewidth=3, color=[0, 0.4470, 0.7410])
plt.xlabel('$x_1$', fontsize=15)
plt.ylabel('$x_2$', fontsize=15)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Feb 17 02:28:28 PM: Your problem has 4 variables, 5 constraints, and 0 parameters.
# (CVXPY) Feb 17 02:28:28 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 17 02:28:28 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 17 02:28:28 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 17 02:28:28 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:28 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Feb 17 02:28:28 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Feb 17 02:28:28 PM: Applying reduction Dcp2Cone
# (CVXPY) Feb 17 02:28:28 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 17 02:28:28 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Feb 17 02:28:28 PM: Applying reduction MOSEK
# (CVXPY) Feb 17 02:28:28 PM: Finished problem compilation (took 9.932e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:28 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Feb 17 02:28:28 PM: Problem
# (CVXPY) Feb 17 02:28:28 PM:   Name                   :
# (CVXPY) Feb 17 02:28:28 PM:   Objective sense        : maximize
# (CVXPY) Feb 17 02:28:28 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Feb 17 02:28:28 PM:   Constraints            : 8
# (CVXPY) Feb 17 02:28:28 PM:   Affine conic cons.     : 0
# (CVXPY) Feb 17 02:28:28 PM:   Disjunctive cons.      : 0
# (CVXPY) Feb 17 02:28:28 PM:   Cones                  : 2
# (CVXPY) Feb 17 02:28:28 PM:   Scalar variables       : 11
# (CVXPY) Feb 17 02:28:28 PM:   Matrix variables       : 2 (scalarized: 13)
# (CVXPY) Feb 17 02:28:28 PM:   Integer variables      : 0
# (CVXPY) Feb 17 02:28:28 PM:
# (CVXPY) Feb 17 02:28:28 PM: Optimizer started.
# (CVXPY) Feb 17 02:28:28 PM: Presolve started.
# (CVXPY) Feb 17 02:28:28 PM: Eliminator started.
# (CVXPY) Feb 17 02:28:28 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 17 02:28:28 PM: Eliminator terminated.
# (CVXPY) Feb 17 02:28:28 PM: Linear dependency checker started.
# (CVXPY) Feb 17 02:28:28 PM: Linear dependency checker terminated.
# (CVXPY) Feb 17 02:28:28 PM: Eliminator started.
# (CVXPY) Feb 17 02:28:28 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 17 02:28:28 PM: Eliminator terminated.
# (CVXPY) Feb 17 02:28:28 PM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Feb 17 02:28:28 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Feb 17 02:28:28 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Feb 17 02:28:28 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Feb 17 02:28:28 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Feb 17 02:28:28 PM: Presolve terminated. Time: 0.00
# (CVXPY) Feb 17 02:28:28 PM: Optimizer  - threads                : 10
# (CVXPY) Feb 17 02:28:28 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Feb 17 02:28:28 PM: Optimizer  - Constraints            : 6
# (CVXPY) Feb 17 02:28:28 PM: Optimizer  - Cones                  : 3
# (CVXPY) Feb 17 02:28:28 PM: Optimizer  - Scalar variables       : 14                conic                  : 9
# (CVXPY) Feb 17 02:28:28 PM: Optimizer  - Semi-definite variables: 1                 scalarized             : 10
# (CVXPY) Feb 17 02:28:28 PM: Factor     - setup time             : 0.00
# (CVXPY) Feb 17 02:28:28 PM: Factor     - dense det. time        : 0.00              GP order time          : 0.00
# (CVXPY) Feb 17 02:28:28 PM: Factor     - nonzeros before factor : 21                after factor           : 21
# (CVXPY) Feb 17 02:28:28 PM: Factor     - dense dim.             : 0                 flops                  : 3.66e+02
# (CVXPY) Feb 17 02:28:28 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Feb 17 02:28:28 PM: 0   1.5e+00  2.0e+02  4.3e+00  0.00e+00   -1.655676798e+00  1.610204003e+00   1.0e+00  0.01
# (CVXPY) Feb 17 02:28:28 PM: 1   4.6e-01  6.2e+01  2.1e+00  -9.26e-01  5.300586852e+00   6.401739048e+00   3.1e-01  0.01
# (CVXPY) Feb 17 02:28:28 PM: 2   1.6e-01  2.2e+01  5.1e-01  -3.77e-02  1.996414657e+00   2.481176316e+00   1.1e-01  0.01
# (CVXPY) Feb 17 02:28:28 PM: 3   4.4e-02  6.0e+00  8.1e-02  5.04e-01   1.269848244e+00   1.394983621e+00   3.0e-02  0.01
# (CVXPY) Feb 17 02:28:28 PM: 4   1.0e-02  1.4e+00  1.0e-02  8.35e-01   6.649295074e-01   6.826126556e-01   7.0e-03  0.01
# (CVXPY) Feb 17 02:28:28 PM: 5   1.1e-03  1.4e-01  3.2e-04  9.57e-01   3.002778707e-01   3.029316067e-01   7.1e-04  0.01
# (CVXPY) Feb 17 02:28:28 PM: 6   2.2e-04  3.0e-02  3.7e-05  9.45e-01   2.560501053e-01   2.559415980e-01   1.5e-04  0.02
# (CVXPY) Feb 17 02:28:28 PM: 7   2.6e-05  3.5e-03  1.5e-06  8.80e-01   2.381408581e-01   2.380969520e-01   1.8e-05  0.02
# (CVXPY) Feb 17 02:28:28 PM: 8   9.6e-07  1.3e-04  1.1e-08  9.85e-01   2.356530757e-01   2.356514866e-01   6.5e-07  0.02
# (CVXPY) Feb 17 02:28:28 PM: 9   9.7e-08  1.3e-05  3.6e-10  1.00e+00   2.355738834e-01   2.355737224e-01   6.6e-08  0.02
# (CVXPY) Feb 17 02:28:28 PM: 10  1.0e-08  1.4e-06  1.2e-11  1.00e+00   2.355668212e-01   2.355668042e-01   6.8e-09  0.02
# (CVXPY) Feb 17 02:28:28 PM: 11  4.8e-10  7.5e-08  1.5e-13  1.00e+00   2.355661111e-01   2.355661105e-01   3.7e-10  0.02
# (CVXPY) Feb 17 02:28:28 PM: Optimizer terminated. Time: 0.02
# (CVXPY) Feb 17 02:28:28 PM:
# (CVXPY) Feb 17 02:28:28 PM:
# (CVXPY) Feb 17 02:28:28 PM: Interior-point solution summary
# (CVXPY) Feb 17 02:28:28 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Feb 17 02:28:28 PM:   Solution status : OPTIMAL
# (CVXPY) Feb 17 02:28:28 PM:   Primal.  obj: 2.3556611113e-01    nrm: 2e+00    Viol.  con: 3e-09    var: 1e-08    barvar: 0e+00    cones: 0e+00
# (CVXPY) Feb 17 02:28:28 PM:   Dual.    obj: 2.3556611050e-01    nrm: 5e+00    Viol.  con: 0e+00    var: 1e-07    barvar: 2e-09    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:28 PM: Problem status: optimal
# (CVXPY) Feb 17 02:28:28 PM: Optimal value: 2.356e-01
# (CVXPY) Feb 17 02:28:28 PM: Compilation took 9.932e-03 seconds
# (CVXPY) Feb 17 02:28:28 PM: Solver (including time spent in interface) took 2.407e-02 seconds
# Optimal value (logdet(P)):  0.23556610222556035
# Optimal solution (P):
#  [[1.43211633 0.64199464]
#  [0.64199464 0.83951319]]
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18617: UserWarning: Argument sub in putvarboundlist: Incorrect array format causing data to be copied
#   warnings.warn("Argument sub in putvarboundlist: Incorrect array format causing data to be copied");
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18925: UserWarning: Argument subj in putclist: Incorrect array format causing data to be copied
#   warnings.warn("Argument subj in putclist: Incorrect array format causing data to be copied");
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18349: UserWarning: Argument sub in putconboundlist: Incorrect array format causing data to be copied
#   warnings.warn("Argument sub in putconboundlist: Incorrect array format causing data to be copied");

# %%
# IV. Conic Programming

# Define matrices and vectors
A = np.array([[3.0, -2.0], [-2.0, 1.0]])
c = np.array([[3.0], [0.0]])

# First optimization problem
x = cp.Variable((2, 1))
# constraints = [x.T @ A @ x <= 0, x >= 0]
constraints = [cp.quad_form(x, A) <= 0, x >= 0]
objective = cp.Minimize(cp.sum_squares(x - c))

# Solve the first optimization problem
problem = cp.Problem(objective, constraints)
problem.solve(solver=cp.MOSEK, verbose=True)

print("Optimal value of x for the first problem:", x.value)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Feb 17 02:28:30 PM: Your problem has 2 variables, 3 constraints, and 0 parameters.
# (CVXPY) Feb 17 02:28:30 PM: It is compliant with the following grammars:
# (CVXPY) Feb 17 02:28:30 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 17 02:28:30 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 17 02:28:30 PM: Your problem is compiled with the CPP canonicalization backend.
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# Cell In[7], line 15
#      13 # Solve the first optimization problem
#      14 problem = cp.Problem(objective, constraints)
# ---> 15 problem.solve(solver=cp.MOSEK, verbose=True)
#      17 print("Optimal value of x for the first problem:", x.value)
#
# File ~/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:503, in Problem.solve(self, *args, **kwargs)
#     501 else:
#     502     solve_func = Problem._solve
# --> 503 return solve_func(self, *args, **kwargs)
#
# File ~/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1073, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1070         self.unpack(chain.retrieve(soln))
#    1071         return self.value
# -> 1073 data, solving_chain, inverse_data = self.get_problem_data(
#    1074     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1075 )
#    1077 if verbose:
#    1078     print(_NUM_SOLVER_STR)
#
# File ~/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:646, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     644 if key != self._cache.key:
#     645     self._cache.invalidate()
# --> 646     solving_chain = self._construct_chain(
#     647         solver=solver, gp=gp,
#     648         enforce_dpp=enforce_dpp,
#     649         ignore_dpp=ignore_dpp,
#     650         canon_backend=canon_backend,
#     651         solver_opts=solver_opts)
#     652     self._cache.key = key
#     653     self._cache.solving_chain = solving_chain
#
# File ~/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:898, in Problem._construct_chain(self, solver, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#     896 candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#     897 self._sort_candidate_solvers(candidate_solvers)
# --> 898 return construct_solving_chain(self, candidate_solvers, gp=gp,
#     899                                enforce_dpp=enforce_dpp,
#     900                                ignore_dpp=ignore_dpp,
#     901                                canon_backend=canon_backend,
#     902                                solver_opts=solver_opts,
#     903                                specified_solver=solver)
#
# File ~/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/cvxpy/reductions/solvers/solving_chain.py:228, in construct_solving_chain(problem, candidates, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts, specified_solver)
#     226 if len(problem.variables()) == 0:
#     227     return SolvingChain(reductions=[ConstantSolver()])
# --> 228 reductions = _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     230 # Process DPP status of the problem.
#     231 dpp_context = 'dcp' if not gp else 'dgp'
#
# File ~/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/cvxpy/reductions/solvers/solving_chain.py:143, in _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     140     elif problem.is_dqcp():
#     141         append += ("\nHowever, the problem does follow DQCP rules. "
#     142                    "Consider calling solve() with `qcp=True`.")
# --> 143     raise DCPError(
#     144         "Problem does not follow DCP rules. Specifically:\n" + append)
#     145 elif gp and not problem.is_dgp():
#     146     append = build_non_disciplined_error_msg(problem, 'DGP')
#
# DCPError: Problem does not follow DCP rules. Specifically:
# The following constraints are not DCP:
# QuadForm(var303, [[3.00 -2.00]
#  [-2.00 1.00]]) <= 0.0 , because the following subexpressions are not:
# |--  QuadForm(var303, [[3.00 -2.00]
#  [-2.00 1.00]])

# %%
# IV. Conic Programming
# Define vectors for second optimization problem
a = np.array([[3], [-2]])
b = np.array([[0], [1]])
c = np.array([[3.0], [0.0]])

# Second optimization problem
x = cp.Variable((2, 1))
# constraints = [cp.norm(a.T @ x) <= b.T @ x]
constraints = [cp.SOC((b.T @ x)[0,0], a.T @ x)]
objective = cp.Minimize(cp.sum_squares(x - c))

# Solve the second optimization problem
problem = cp.Problem(objective, constraints)
problem.solve(solver=cp.MOSEK, verbose=True)

print("Optimal value of x for the second problem:", x.value)

# Plotting
x1vector = np.arange(-5, 6, 0.5)
x2vector = np.arange(0, 6, 0.5)

def conePlot2d(a, b):
    coneplot = False
    if np.sign(a[0]) * np.sign(a[1]) == 1:
        g1vector = (b[0] - np.abs(a[0])) / (np.abs(a[1]) - b[1]) * x1vector
        g2vector = (b[0] - np.abs(a[0])) / (np.abs(a[1]) - b[1]) * x1vector
        coneplot = True
    elif np.sign(a[0]) * np.sign(a[1]) == -1:
        g1vector = (b[0] + np.abs(a[0])) / (np.abs(a[1]) - b[1]) * x1vector
        g2vector = (-b[0] + np.abs(a[0])) / (np.abs(a[1]) + b[1]) * x1vector
        coneplot = True

    if coneplot:
        x1Top = [x1vector[np.argmax(g1vector)], x1vector[np.argmax(g2vector)]]
        x2Top = [np.max(g1vector), np.max(g2vector)]
        
        plt.fill([0, np.min(x1Top), np.max(x1Top), 0], [0, np.min(x2Top), np.max(x2Top), 0], 'g', alpha=0.5, edgecolor='k', label='Cone')
        plt.xlim([-5, 5])
        plt.ylim([0, 5])

plt.figure()
plt.contour(x1vector, x2vector, x2vector[:, np.newaxis] ** 2 + (x1vector - 3)[np.newaxis, :] ** 2, levels=range(0, 31, 2), linestyles='--', colors='b', alpha=0.5, label='$f(\\mathbf{x})$')
conePlot2d(a, b)
plt.scatter(x.value[0], x.value[1], color='r', marker='*', label='$x^*$')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Optimization Result')
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.xlim([-5, 5])
plt.ylim([0, 6])
plt.show()
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Feb 17 02:28:42 PM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Feb 17 02:28:42 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 17 02:28:42 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 17 02:28:42 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 17 02:28:42 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:42 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Feb 17 02:28:42 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Feb 17 02:28:42 PM: Applying reduction Dcp2Cone
# (CVXPY) Feb 17 02:28:42 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 17 02:28:42 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Feb 17 02:28:42 PM: Applying reduction MOSEK
# (CVXPY) Feb 17 02:28:42 PM: Finished problem compilation (took 7.706e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:42 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Feb 17 02:28:42 PM: Problem
# (CVXPY) Feb 17 02:28:42 PM:   Name                   :
# (CVXPY) Feb 17 02:28:42 PM:   Objective sense        : maximize
# (CVXPY) Feb 17 02:28:42 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Feb 17 02:28:42 PM:   Constraints            : 3
# (CVXPY) Feb 17 02:28:42 PM:   Affine conic cons.     : 0
# (CVXPY) Feb 17 02:28:42 PM:   Disjunctive cons.      : 0
# (CVXPY) Feb 17 02:28:42 PM:   Cones                  : 2
# (CVXPY) Feb 17 02:28:42 PM:   Scalar variables       : 6
# (CVXPY) Feb 17 02:28:42 PM:   Matrix variables       : 0
# (CVXPY) Feb 17 02:28:42 PM:   Integer variables      : 0
# (CVXPY) Feb 17 02:28:42 PM:
# (CVXPY) Feb 17 02:28:42 PM: Optimizer started.
# (CVXPY) Feb 17 02:28:42 PM: Presolve started.
# (CVXPY) Feb 17 02:28:42 PM: Linear dependency checker started.
# (CVXPY) Feb 17 02:28:42 PM: Linear dependency checker terminated.
# (CVXPY) Feb 17 02:28:42 PM: Eliminator started.
# (CVXPY) Feb 17 02:28:42 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 17 02:28:42 PM: Eliminator terminated.
# (CVXPY) Feb 17 02:28:42 PM: Eliminator started.
# (CVXPY) Feb 17 02:28:42 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 17 02:28:42 PM: Eliminator terminated.
# (CVXPY) Feb 17 02:28:42 PM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Feb 17 02:28:42 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Feb 17 02:28:42 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Feb 17 02:28:42 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Feb 17 02:28:42 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Feb 17 02:28:42 PM: Presolve terminated. Time: 0.00
# (CVXPY) Feb 17 02:28:42 PM: Optimizer  - threads                : 10
# (CVXPY) Feb 17 02:28:42 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Feb 17 02:28:42 PM: Optimizer  - Constraints            : 3
# (CVXPY) Feb 17 02:28:42 PM: Optimizer  - Cones                  : 2
# (CVXPY) Feb 17 02:28:42 PM: Optimizer  - Scalar variables       : 6                 conic                  : 6
# (CVXPY) Feb 17 02:28:42 PM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Feb 17 02:28:42 PM: Factor     - setup time             : 0.00
# (CVXPY) Feb 17 02:28:42 PM: Factor     - dense det. time        : 0.00              GP order time          : 0.00
# (CVXPY) Feb 17 02:28:42 PM: Factor     - nonzeros before factor : 6                 after factor           : 6
# (CVXPY) Feb 17 02:28:42 PM: Factor     - dense dim.             : 0                 flops                  : 5.20e+01
# (CVXPY) Feb 17 02:28:42 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Feb 17 02:28:42 PM: 0   2.5e-01  6.0e+00  2.0e+00  0.00e+00   -1.000000000e+00  -0.000000000e+00  1.0e+00  0.00
# (CVXPY) Feb 17 02:28:42 PM: 1   5.3e-02  1.3e+00  6.5e-01  -7.12e-01  2.456028623e+00   1.384687968e+00   2.1e-01  0.01
# (CVXPY) Feb 17 02:28:42 PM: 2   1.2e-02  2.9e-01  6.8e-02  3.22e-01   3.961181229e+00   3.815096166e+00   4.9e-02  0.01
# (CVXPY) Feb 17 02:28:42 PM: 3   6.6e-05  1.6e-03  4.2e-05  8.10e-01   4.498783331e+00   4.494604789e+00   2.6e-04  0.01
# (CVXPY) Feb 17 02:28:42 PM: 4   2.0e-06  4.9e-05  2.3e-07  9.98e-01   4.499988851e+00   4.499858564e+00   8.1e-06  0.01
# (CVXPY) Feb 17 02:28:42 PM: 5   1.1e-07  2.8e-06  3.0e-09  1.00e+00   4.500000075e+00   4.499992742e+00   4.6e-07  0.01
# (CVXPY) Feb 17 02:28:42 PM: 6   2.9e-09  6.9e-08  1.2e-11  1.00e+00   4.500000011e+00   4.499999828e+00   1.1e-08  0.01
# (CVXPY) Feb 17 02:28:42 PM: 7   7.1e-12  1.9e-10  1.7e-15  1.00e+00   4.500000000e+00   4.499999999e+00   3.2e-11  0.01
# (CVXPY) Feb 17 02:28:42 PM: Optimizer terminated. Time: 0.01
# (CVXPY) Feb 17 02:28:42 PM:
# (CVXPY) Feb 17 02:28:42 PM:
# (CVXPY) Feb 17 02:28:42 PM: Interior-point solution summary
# (CVXPY) Feb 17 02:28:42 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Feb 17 02:28:42 PM:   Solution status : OPTIMAL
# (CVXPY) Feb 17 02:28:42 PM:   Primal.  obj: 4.5000000000e+00    nrm: 3e+00    Viol.  con: 1e-10    var: 0e+00    cones: 0e+00
# (CVXPY) Feb 17 02:28:42 PM:   Dual.    obj: 4.4999999995e+00    nrm: 5e+00    Viol.  con: 0e+00    var: 8e-10    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:28:42 PM: Problem status: optimal
# (CVXPY) Feb 17 02:28:42 PM: Optimal value: 4.500e+00
# (CVXPY) Feb 17 02:28:42 PM: Compilation took 7.706e-03 seconds
# (CVXPY) Feb 17 02:28:42 PM: Solver (including time spent in interface) took 1.731e-02 seconds
# Optimal value of x for the second problem: [[1.49999803]
#  [1.49999803]]
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18617: UserWarning: Argument sub in putvarboundlist: Incorrect array format causing data to be copied
#   warnings.warn("Argument sub in putvarboundlist: Incorrect array format causing data to be copied");
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18925: UserWarning: Argument subj in putclist: Incorrect array format causing data to be copied
#   warnings.warn("Argument subj in putclist: Incorrect array format causing data to be copied");
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/mosek/__init__.py:18349: UserWarning: Argument sub in putconboundlist: Incorrect array format causing data to be copied
#   warnings.warn("Argument sub in putconboundlist: Incorrect array format causing data to be copied");
# /var/folders/_b/9ytk4f9x6nj3vnx_qmdfjwf80000gn/T/ipykernel_9309/1014689722.py:43: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(x1vector, x2vector, x2vector[:, np.newaxis] ** 2 + (x1vector - 3)[np.newaxis, :] ** 2, levels=range(0, 31, 2), linestyles='--', colors='b', alpha=0.5, label='$f(\\mathbf{x})$')
