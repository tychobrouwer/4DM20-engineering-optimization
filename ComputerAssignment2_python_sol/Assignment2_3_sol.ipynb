# %%
# Exercise 3: Quadratic Programming

# %%
import cvxpy as cp
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['text.usetex'] = True

# %%
# Optimization variables
x1 = cp.Variable(1)
x2 = cp.Variable(1)

# Define constraints
constraints = [
    x1 + 2*x2 <= 10,
    7*x1 - x2 <= 15,
    x1 >= 0,
    x2 >= 0]

# Define objective
objective = (x1 - 4) ** 2 + (x2 - 4) ** 2

# Solve problem
problem = cp.Problem(cp.Minimize(objective), constraints)
problem.solve(solver=cp.ECOS, verbose=True)

# Print optimal values of x1 and x2
print("Optimal value of x1:", x1.value)
print("Optimal value of x2:", x2.value)

# Plotting
x1vector = np.arange(0, 10.5, 0.5)
x2vector = np.arange(0, 10.5, 0.5)
X1, X2 = np.meshgrid(x1vector, x2vector)
Z = (X1-4)**2+(X2-4)**2

plt.figure()
# Objective function contour
fx=plt.contour(X1, X2, Z, levels=np.arange(0, 10.5, 1), linestyles='--', colors='grey')
plt.clabel(fx, inline=1, fontsize=10) #Places values of f at the lines
plt.plot(x1vector, 5 - x1vector / 2, 'green', label='$g_1(x)$', zorder=1)
plt.plot(x1vector, 7 * x1vector - 15, 'b', label='$g_2(x)$', zorder=1)
# Optimal point
plt.scatter(x1.value, x2.value, color='r', marker='*', s=200, label='$x^*$', zorder=2)
plt.xlim([2, 5])
plt.ylim([3, 6])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Optimization Result')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Feb 17 02:55:24 PM: Your problem has 2 variables, 4 constraints, and 0 parameters.
# (CVXPY) Feb 17 02:55:24 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 17 02:55:24 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 17 02:55:24 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 17 02:55:24 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:55:24 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Feb 17 02:55:24 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Feb 17 02:55:24 PM: Applying reduction Dcp2Cone
# (CVXPY) Feb 17 02:55:24 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 17 02:55:24 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Feb 17 02:55:24 PM: Applying reduction ECOS
# (CVXPY) Feb 17 02:55:24 PM: Finished problem compilation (took 1.000e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:55:24 PM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 17 02:55:24 PM: Problem status: optimal
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
# (CVXPY) Feb 17 02:55:24 PM: Optimal value: 1.889e+00
#  0  +8.564e-17  -1.339e+01  +3e+01  2e-01  1e-01  1e+00  5e+00    ---    ---    1  1  - |  -  -
#  1  +2.102e+00  +6.144e-01  +5e+00  3e-02  2e-02  9e-01  1e+00  0.9465  2e-01   1  1  2 |  0  0
#  2  +1.784e+00  +1.625e+00  +6e-01  4e-03  2e-03  1e-01  1e-01  0.8844  8e-03   2  1  1 |  0  0
#  3  +1.865e+00  +1.789e+00  +3e-01  2e-03  9e-04  6e-02  5e-02  0.7587  2e-01   2  2  2 |  0  0
#  4  +1.883e+00  +1.874e+00  +3e-02  2e-04  1e-04  6e-03  6e-03  0.8847  4e-03   2  1  1 |  0  0
#  5  +1.889e+00  +1.887e+00  +5e-03  3e-05  2e-05  6e-04  8e-04  0.9379  8e-02   2  1  1 |  0  0
#  6  +1.889e+00  +1.889e+00  +7e-04  4e-06  2e-06  1e-04  1e-04  0.8601  6e-03   2  1  1 |  0  0
#  7  +1.889e+00  +1.889e+00  +1e-04  8e-07  4e-07  2e-05  2e-05  0.9156  1e-01   2  1  1 |  0  0
#  8  +1.889e+00  +1.889e+00  +2e-05  1e-07  7e-08  3e-06  4e-06  0.8570  7e-03   1  1  1 |  0  0
#  9  +1.889e+00  +1.889e+00  +4e-06  2e-08  1e-08  5e-07  7e-07  0.9167  1e-01   2  1  1 |  0  0
# 10  +1.889e+00  +1.889e+00  +6e-07  4e-09  2e-09  8e-08  1e-07  0.8475  9e-03   1  1  1 |  0  0
# 11  +1.889e+00  +1.889e+00  +1e-07  8e-10  4e-10  2e-08  2e-08  0.9035  1e-01   2  1  1 |  0  0
# 12  +1.889e+00  +1.889e+00  +2e-08  1e-10  7e-11  3e-09  4e-09  0.8336  1e-02   2  1  1 |  0  0
# 13  +1.889e+00  +1.889e+00  +5e-09  3e-11  2e-11  6e-10  8e-10  0.8885  1e-01   3  1  1 |  0  0
#
# OPTIMAL (within feastol=2.9e-11, reltol=2.6e-09, abstol=4.9e-09).
# Runtime: 0.000424 seconds.
#
# (CVXPY) Feb 17 02:55:24 PM: Compilation took 1.000e-02 seconds
# (CVXPY) Feb 17 02:55:24 PM: Solver (including time spent in interface) took 6.380e-04 seconds
# Optimal value of x1: [2.66666667]
# Optimal value of x2: [3.66666667]
# /Users/leonardopedroso/Documents/Research/Teaching/4DM20 EngOpt/2025/Computer Assignments/ComputerAssignment2/ComputerAssignment2.withSolutions/python/.venv/lib/python3.10/site-packages/cvxpy/reductions/solvers/solving_chain.py:356: FutureWarning:
#     You specified your problem should be solved by ECOS. Starting in
#     CXVPY 1.6.0, ECOS will no longer be installed by default with CVXPY.
#     Please either add ECOS as an explicit install dependency to your project
#     or switch to our new default solver, Clarabel, by either not specifying a
#     solver argument or specifying ``solver=cp.CLARABEL``. To suppress this
#     warning while continuing to use ECOS, you can filter this warning using
#     Python's ``warnings`` module until you are using 1.6.0.
#
#   warnings.warn(ECOS_DEP_DEPRECATION_MSG, FutureWarning)
